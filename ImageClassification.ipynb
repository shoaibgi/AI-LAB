# %%
import cv2
import os

def video_to_images(video_path, output_folder, prefix="frame", image_format="jpg"):
    # Create output directory if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # No more frames to read

        # Construct image file name
        filename = f"{prefix}_{frame_count:05d}.{image_format}"
        filepath = os.path.join(output_folder, filename)

        # Save the frame as an image
        cv2.imwrite(filepath, frame)

        frame_count += 1

    cap.release()
    print(f"Saved {frame_count} frames to {output_folder}")

# Example usage
video_path = "highway.mp4"
output_folder = "D:\Training data\highway"
video_to_images(video_path, output_folder)

# %%
from ultralytics import YOLO
model=YOLO("custom.pt")
results=model("highway.mp4",save=True)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/4517) D:\yolov11custom\highway.mp4: 384x640 3 Pickup Trucks, 2 Sedan Toyota Corollas, 12 Transport Trucks, 123.4ms
# video 1/1 (frame 2/4517) D:\yolov11custom\highway.mp4: 384x640 4 Pickup Trucks, 2 Sedan Toyota Corollas, 12 Transport Trucks, 20.9ms
# video 1/1 (frame 3/4517) D:\yolov11custom\highway.mp4: 384x640 3 Pickup Trucks, 1 SUV Toyota RAV4, 2 Sedan Toyota Corollas, 13 Transport Trucks, 17.8ms
# ...
